# %% [raw]
# # Observations
#
# * City temperatures peak at +20 N latitude, rather than at the equator. This is likely because the data was pulled in June 19, 2018, a few days before the Northern Hemisphere's Summer Equinox. A year-long data set would likely see temperature peak at the equator, but only same-day weather data is not available from the free tier of the Open Weather Map API.
#
# * City temperatures in the southern hemisphere are clustered more closely together at similar latitudes than in northern hemisphere cities. The southern cities are packed tighter on the 'City Latitude v. Max Temperature' chart, with fewer obvious outliers. This is likely due to narrower non-Antarctic landmasses in the Southern Hemisphere. On the 'City Coordinate Distribution' chart (mirroring a world map), the negative latitude cities are clustered longtitudinally around -60 W (South America), +25 E (Subequatorial Africa), and +150 E (Oceania and much of Indonesia). Positive latitude cities have a much more broad and even longitudinal distribution, reflecting more available landmass East-West and more thus greater potential variability.
#
# * There are no cities further south in latitude than -55 S, corresponding with the southern-most tip of Argentina.
#
# * Humidity, Wind Speed, and Cloud Cover do not have any discernable relationship with Latitude.

# %%
#import dependencies

import matplotlib.pyplot as plt
import json
import random
import pandas as pd
from api_keys import weather_key
from citipy import citipy
import requests
import time

# %%
# Step 1: Generate list of random cities

# Use random to generate a list of lat + long.
# Use citipy to find nearest city to coordinates

cities = []

# This acts as a check to ensure that the generated city in loop is not a repeat
unique_cities_check = []

# Below loop makes up to 10,000 attempts to generate list of 1000 cities with
# random lat/long generation and CitiPy's nearest_city().
# Random coordinate generation results in many duplicates, due the likelihood of
# the 'nearest city' being on an island in the middle of the ocean or on the edge of continents.
# From sampling, reaching the desired number of cities takes roughly 3x the iterations.
# E.g. generating 500 cities takes roughly 1500 iterations.
# 10,000 attempts should be sufficient to generate 1000 cities and the loop should only run
# around 3000 times.

# I also expect about 13% of CitiPy generated cities to throw an error when plugged into the
# Open Weather Map API city search, leaving me with a final sample of roughly 870 cities.

# One of the problem parameters is at least 500 cities.
# I could hardcode failsafe to run additional code if final number of cities is <500
# but it's simpler to generate enough cities that falling below 500 is very unlikely.

for i in range(10000):

    if len(cities) < 1000:
        lat = random.uniform(-90.0,90.0)
        long = random.uniform(-180.0,180.0)
        
        city = citipy.nearest_city(lat,long)
        
        city_country = city.city_name + ' ' + city.country_code
        
        if city_country not in unique_cities_check:
            unique_cities_check.append(city_country)
            cities.append([city.city_name, city.country_code])
                    
    else:
        break

# %%
# Step 2
# Generate weather data based on the city and country data from OpenWeatherMap API

url = 'https://api.openweathermap.org/data/2.5/weather'

# Weather outputs
weather_data_list = []

for i in range(len(cities)):
    city = cities[i][0]
    country = cities[i][1]
        
    query_params={'q': city + ',' + country,
                  'units': 'imperial',
                  'appid': weather_key}
    
    response = requests.get(url, params = query_params).json()

    # Try-except because not every city in CityPy is found in OWM,
    # about 13% attrition from the 1000 in the cities list
    try:
        weather_data_list.append({'City': city,
                                  'Country': country,
                                  'Longitude': response['coord']['lon'], 
                                  'Latitude': response['coord']['lat'],
                                  'Max Temperature': response['main']['temp_max'],
                                  'Humidity': response['main']['humidity'],
                                  'Cloud Cover': response['clouds']['all'],
                                  'Wind Speed': response['wind']['speed']
                                 })
        print(f'Running data for {city}: {i} of 1000')
    except:
        print(f'Data returned null, Skipping...')
        pass
    time.sleep(1)
# Out:
# Running data for sitka: 0 of 1000
# Running data for aden: 1 of 1000
# Running data for nishihara: 2 of 1000
# Data returned null, Skipping...
# Running data for marystown: 4 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for punta arenas: 7 of 1000
# Running data for saint george: 8 of 1000
# Running data for rikitea: 9 of 1000
# Running data for hobart: 10 of 1000
# Running data for new norfolk: 11 of 1000
# Running data for kalmunai: 12 of 1000
# Running data for yumen: 13 of 1000
# Running data for longyearbyen: 14 of 1000
# Running data for mar del plata: 15 of 1000
# Data returned null, Skipping...
# Running data for lakes entrance: 17 of 1000
# Running data for torbay: 18 of 1000
# Running data for hasaki: 19 of 1000
# Running data for tuku: 20 of 1000
# Running data for haines junction: 21 of 1000
# Running data for port lincoln: 22 of 1000
# Running data for pattoki: 23 of 1000
# Running data for albany: 24 of 1000
# Running data for atuona: 25 of 1000
# Data returned null, Skipping...
# Running data for bilma: 27 of 1000
# Running data for malanje: 28 of 1000
# Running data for viseu: 29 of 1000
# Running data for dikson: 30 of 1000
# Running data for mayumba: 31 of 1000
# Running data for victoria: 32 of 1000
# Running data for nikolskoye: 33 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for kodiak: 36 of 1000
# Data returned null, Skipping...
# Running data for avarua: 38 of 1000
# Running data for nelson bay: 39 of 1000
# Running data for ushuaia: 40 of 1000
# Running data for lompoc: 41 of 1000
# Running data for america dourada: 42 of 1000
# Running data for kattivakkam: 43 of 1000
# Running data for sulangan: 44 of 1000
# Running data for cape town: 45 of 1000
# Running data for coihaique: 46 of 1000
# Running data for magadan: 47 of 1000
# Running data for gobabis: 48 of 1000
# Running data for east london: 49 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for chulym: 53 of 1000
# Running data for kapaa: 54 of 1000
# Data returned null, Skipping...
# Running data for fortuna: 56 of 1000
# Running data for hithadhoo: 57 of 1000
# Running data for bethel: 58 of 1000
# Running data for tuktoyaktuk: 59 of 1000
# Running data for tabou: 60 of 1000
# Running data for shenjiamen: 61 of 1000
# Running data for lavrentiya: 62 of 1000
# Running data for narsaq: 63 of 1000
# Running data for ratnagiri: 64 of 1000
# Running data for almaty: 65 of 1000
# Running data for tasiilaq: 66 of 1000
# Running data for kirakira: 67 of 1000
# Running data for yellowknife: 68 of 1000
# Running data for jamestown: 69 of 1000
# Running data for deputatskiy: 70 of 1000
# Running data for kaitangata: 71 of 1000
# Running data for qaqortoq: 72 of 1000
# Running data for busselton: 73 of 1000
# Running data for qaanaaq: 74 of 1000
# Data returned null, Skipping...
# Running data for luderitz: 76 of 1000
# Running data for broome: 77 of 1000
# Running data for puerto colombia: 78 of 1000
# Running data for bambous virieux: 79 of 1000
# Running data for chuy: 80 of 1000
# Running data for bredasdorp: 81 of 1000
# Running data for xiamen: 82 of 1000
# Running data for palembang: 83 of 1000
# Running data for rudnogorsk: 84 of 1000
# Running data for castro: 85 of 1000
# Running data for havre: 86 of 1000
# Running data for rocha: 87 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for hermanus: 90 of 1000
# Running data for ivanivka: 91 of 1000
# Running data for mahibadhoo: 92 of 1000
# Running data for vestmannaeyjar: 93 of 1000
# Running data for kieta: 94 of 1000
# Running data for pedernales: 95 of 1000
# Data returned null, Skipping...
# Running data for vaini: 97 of 1000
# Running data for butaritari: 98 of 1000
# Running data for arraial do cabo: 99 of 1000
# Running data for manavalakurichi: 100 of 1000
# Running data for zhangjiakou: 101 of 1000
# Running data for vardo: 102 of 1000
# Running data for saint-louis: 103 of 1000
# Running data for dutlwe: 104 of 1000
# Running data for mount isa: 105 of 1000
# Data returned null, Skipping...
# Running data for carnarvon: 107 of 1000
# Running data for lebu: 108 of 1000
# Running data for sovetskaya: 109 of 1000
# Running data for atambua: 110 of 1000
# Running data for cherskiy: 111 of 1000
# Running data for talcahuano: 112 of 1000
# Running data for saldanha: 113 of 1000
# Running data for dunedin: 114 of 1000
# Running data for usinsk: 115 of 1000
# Running data for kabinda: 116 of 1000
# Running data for hobyo: 117 of 1000
# Running data for hambantota: 118 of 1000
# Data returned null, Skipping...
# Running data for bluff: 120 of 1000
# Running data for port alfred: 121 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for sanchez: 124 of 1000
# Running data for kandrian: 125 of 1000
# Running data for san felipe: 126 of 1000
# Running data for strezhevoy: 127 of 1000
# Running data for faanui: 128 of 1000
# Running data for ormara: 129 of 1000
# Running data for mtwara: 130 of 1000
# Running data for banda aceh: 131 of 1000
# Running data for severo-kurilsk: 132 of 1000
# Running data for afrikanda: 133 of 1000
# Running data for narbonne: 134 of 1000
# Running data for bridlington: 135 of 1000
# Running data for chapais: 136 of 1000
# Running data for saurimo: 137 of 1000
# Running data for sola: 138 of 1000
# Running data for balaipungut: 139 of 1000
# Running data for kendari: 140 of 1000
# Running data for jilib: 141 of 1000
# Data returned null, Skipping...
# Running data for muzhi: 143 of 1000
# Running data for srednekolymsk: 144 of 1000
# Running data for siddipet: 145 of 1000
# Running data for norman wells: 146 of 1000
# Running data for touros: 147 of 1000
# Data returned null, Skipping...
# Running data for sirhind: 149 of 1000
# Running data for barrow: 150 of 1000
# Running data for aswan: 151 of 1000
# Running data for khatanga: 152 of 1000
# Running data for portland: 153 of 1000
# Running data for port hedland: 154 of 1000
# Running data for denpasar: 155 of 1000
# Running data for kyakhta: 156 of 1000
# Running data for viedma: 157 of 1000
# Running data for katsuura: 158 of 1000
# Running data for adrar: 159 of 1000
# Data returned null, Skipping...
# Running data for olonets: 161 of 1000
# Data returned null, Skipping...
# Running data for aksum: 163 of 1000
# Data returned null, Skipping...
# Running data for esperance: 165 of 1000
# Running data for port hardy: 166 of 1000
# Data returned null, Skipping...
# Running data for puerto ayora: 168 of 1000
# Running data for darhan: 169 of 1000
# Running data for piacabucu: 170 of 1000
# Running data for camacha: 171 of 1000
# Running data for padang: 172 of 1000
# Running data for salalah: 173 of 1000
# Running data for linxia: 174 of 1000
# Data returned null, Skipping...
# Running data for biak: 176 of 1000
# Running data for alofi: 177 of 1000
# Running data for smithers: 178 of 1000
# Running data for haverfordwest: 179 of 1000
# Running data for abancay: 180 of 1000
# Running data for solnechnyy: 181 of 1000
# Running data for ilulissat: 182 of 1000
# Running data for gigmoto: 183 of 1000
# Running data for igdir: 184 of 1000
# Running data for flin flon: 185 of 1000
# Running data for sawtell: 186 of 1000
# Running data for waitati: 187 of 1000
# Running data for skaelskor: 188 of 1000
# Running data for clyde river: 189 of 1000
# Running data for novikovo: 190 of 1000
# Running data for tvoroyri: 191 of 1000
# Running data for lagoa: 192 of 1000
# Running data for geraldton: 193 of 1000
# Data returned null, Skipping...
# Running data for ust-ilimsk: 195 of 1000
# Running data for georgetown: 196 of 1000
# Running data for gopalpur: 197 of 1000
# Data returned null, Skipping...
# Running data for pacific grove: 199 of 1000
# Running data for zhezkazgan: 200 of 1000
# Running data for talnakh: 201 of 1000
# Running data for iida: 202 of 1000
# Running data for pascagoula: 203 of 1000
# Running data for mahebourg: 204 of 1000
# Running data for bajos de haina: 205 of 1000
# Running data for hereford: 206 of 1000
# Data returned null, Skipping...
# Running data for nieuw amsterdam: 208 of 1000
# Running data for cidreira: 209 of 1000
# Running data for oktyabrskoye: 210 of 1000
# Running data for buala: 211 of 1000
# Running data for troitskoye: 212 of 1000
# Running data for fomboni: 213 of 1000
# Running data for chokurdakh: 214 of 1000
# Running data for ahipara: 215 of 1000
# Running data for nyurba: 216 of 1000
# Running data for athabasca: 217 of 1000
# Running data for cabo san lucas: 218 of 1000
# Running data for provideniya: 219 of 1000
# Running data for lac du bonnet: 220 of 1000
# Running data for auki: 221 of 1000
# Data returned null, Skipping...
# Running data for liusha: 223 of 1000
# Running data for zeya: 224 of 1000
# Running data for shaunavon: 225 of 1000
# Running data for iqaluit: 226 of 1000
# Running data for mount gambier: 227 of 1000
# Running data for marrakesh: 228 of 1000
# Running data for ponta do sol: 229 of 1000
# Running data for vega de alatorre: 230 of 1000
# Running data for terrace: 231 of 1000
# Data returned null, Skipping...
# Running data for arman: 233 of 1000
# Running data for narasannapeta: 234 of 1000
# Running data for kalemie: 235 of 1000
# Running data for salair: 236 of 1000
# Running data for saskylakh: 237 of 1000
# Running data for yanaul: 238 of 1000
# Data returned null, Skipping...
# Running data for pimentel: 240 of 1000
# Running data for sungaipenuh: 241 of 1000
# Running data for isla vista: 242 of 1000
# Running data for sweetwater: 243 of 1000
# Running data for sao filipe: 244 of 1000
# Running data for bandarbeyla: 245 of 1000
# Running data for bajil: 246 of 1000
# Running data for oyama: 247 of 1000
# Data returned null, Skipping...
# Running data for atar: 249 of 1000
# Running data for montana: 250 of 1000
# Running data for guerrero negro: 251 of 1000
# Data returned null, Skipping...
# Running data for udachnyy: 253 of 1000
# Running data for hilo: 254 of 1000
# Running data for riyadh: 255 of 1000
# Running data for puerto escondido: 256 of 1000
# Running data for souillac: 257 of 1000
# Running data for san juan: 258 of 1000
# Running data for medea: 259 of 1000
# Running data for thamaga: 260 of 1000
# Running data for tuy hoa: 261 of 1000
# Running data for kerema: 262 of 1000
# Running data for pailon: 263 of 1000
# Running data for colac: 264 of 1000
# Running data for makurdi: 265 of 1000
# Running data for port-gentil: 266 of 1000
# Running data for gainesville: 267 of 1000
# Running data for diamantino: 268 of 1000
# Running data for killybegs: 269 of 1000
# Running data for mahajanga: 270 of 1000
# Running data for pierre: 271 of 1000
# Running data for victoria point: 272 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for aberdeen: 275 of 1000
# Data returned null, Skipping...
# Running data for eureka: 277 of 1000
# Data returned null, Skipping...
# Running data for haysville: 279 of 1000
# Data returned null, Skipping...
# Running data for loukhi: 281 of 1000
# Running data for la union: 282 of 1000
# Running data for olinda: 283 of 1000
# Running data for thompson: 284 of 1000
# Running data for sorong: 285 of 1000
# Running data for college: 286 of 1000
# Running data for ottawa: 287 of 1000
# Data returned null, Skipping...
# Running data for comodoro rivadavia: 289 of 1000
# Running data for henties bay: 290 of 1000
# Running data for ouallam: 291 of 1000
# Running data for manjacaze: 292 of 1000
# Running data for port elizabeth: 293 of 1000
# Data returned null, Skipping...
# Running data for karla: 295 of 1000
# Running data for poum: 296 of 1000
# Running data for tiksi: 297 of 1000
# Data returned null, Skipping...
# Running data for raudeberg: 299 of 1000
# Running data for egvekinot: 300 of 1000
# Running data for baykit: 301 of 1000
# Running data for kyra: 302 of 1000
# Running data for mehamn: 303 of 1000
# Running data for issia: 304 of 1000
# Running data for garango: 305 of 1000
# Running data for tautira: 306 of 1000
# Running data for berlevag: 307 of 1000
# Running data for mizque: 308 of 1000
# Running data for vereeniging: 309 of 1000
# Running data for saint-augustin: 310 of 1000
# Running data for havoysund: 311 of 1000
# Running data for ust-nera: 312 of 1000
# Running data for poroshkovo: 313 of 1000
# Running data for sorgun: 314 of 1000
# Running data for lorengau: 315 of 1000
# Running data for yakovlevka: 316 of 1000
# Running data for ribeira grande: 317 of 1000
# Running data for constitucion: 318 of 1000
# Running data for beringovskiy: 319 of 1000
# Running data for itarema: 320 of 1000
# Running data for san patricio: 321 of 1000
# Running data for sarangani: 322 of 1000
# Running data for fraga: 323 of 1000
# Running data for santa rosa: 324 of 1000
# Running data for vanavara: 325 of 1000
# Running data for pangnirtung: 326 of 1000
# Data returned null, Skipping...
# Running data for ugoofaaru: 328 of 1000
# Running data for pitimbu: 329 of 1000
# Running data for cockburn town: 330 of 1000
# Running data for sioux lookout: 331 of 1000
# Running data for acajutla: 332 of 1000
# Running data for leningradskiy: 333 of 1000
# Running data for phek: 334 of 1000
# Running data for fuyang: 335 of 1000
# Running data for san rafael: 336 of 1000
# Running data for chicama: 337 of 1000
# Running data for jaffna: 338 of 1000
# Running data for klaksvik: 339 of 1000
# Running data for khanpur: 340 of 1000
# Running data for havre-saint-pierre: 341 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for tuatapere: 345 of 1000
# Running data for honningsvag: 346 of 1000
# Running data for tynda: 347 of 1000
# Running data for vila velha: 348 of 1000
# Data returned null, Skipping...
# Running data for biscarrosse: 350 of 1000
# Running data for xaghra: 351 of 1000
# Running data for abnub: 352 of 1000
# Running data for reconquista: 353 of 1000
# Running data for bhag: 354 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for graaff-reinet: 357 of 1000
# Running data for tavda: 358 of 1000
# Running data for mnogovershinnyy: 359 of 1000
# Running data for kavieng: 360 of 1000
# Running data for ancud: 361 of 1000
# Data returned null, Skipping...
# Running data for yangambi: 363 of 1000
# Running data for thohoyandou: 364 of 1000
# Running data for vung tau: 365 of 1000
# Data returned null, Skipping...
# Running data for ust-ishim: 367 of 1000
# Running data for coquimbo: 368 of 1000
# Running data for monywa: 369 of 1000
# Running data for erzin: 370 of 1000
# Data returned null, Skipping...
# Running data for kahului: 372 of 1000
# Running data for tsabong: 373 of 1000
# Running data for juneau: 374 of 1000
# Running data for herat: 375 of 1000
# Running data for ilo: 376 of 1000
# Running data for svetlogorsk: 377 of 1000
# Running data for tinaquillo: 378 of 1000
# Running data for zhaotong: 379 of 1000
# Running data for nuevo progreso: 380 of 1000
# Running data for taoudenni: 381 of 1000
# Data returned null, Skipping...
# Running data for kovur: 383 of 1000
# Running data for dubbo: 384 of 1000
# Running data for dicabisagan: 385 of 1000
# Running data for tokur: 386 of 1000
# Running data for isangel: 387 of 1000
# Running data for zaysan: 388 of 1000
# Running data for nanortalik: 389 of 1000
# Running data for sisimiut: 390 of 1000
# Running data for san andres: 391 of 1000
# Running data for tura: 392 of 1000
# Running data for mareeba: 393 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for jahazpur: 396 of 1000
# Running data for cayenne: 397 of 1000
# Running data for kose: 398 of 1000
# Running data for marawi: 399 of 1000
# Running data for vienne: 400 of 1000
# Running data for kulunda: 401 of 1000
# Running data for sabya: 402 of 1000
# Running data for tibati: 403 of 1000
# Data returned null, Skipping...
# Running data for grindavik: 405 of 1000
# Data returned null, Skipping...
# Running data for great yarmouth: 407 of 1000
# Running data for karatsu: 408 of 1000
# Running data for paamiut: 409 of 1000
# Running data for christchurch: 410 of 1000
# Running data for makasar: 411 of 1000
# Running data for labuan: 412 of 1000
# Running data for virginia beach: 413 of 1000
# Running data for russell: 414 of 1000
# Running data for broken hill: 415 of 1000
# Running data for aklavik: 416 of 1000
# Running data for wattegama: 417 of 1000
# Running data for green river: 418 of 1000
# Running data for nome: 419 of 1000
# Running data for ostrovnoy: 420 of 1000
# Running data for tiznit: 421 of 1000
# Running data for shunyi: 422 of 1000
# Running data for peniche: 423 of 1000
# Running data for high level: 424 of 1000
# Running data for namatanai: 425 of 1000
# Running data for mabaruma: 426 of 1000
# Data returned null, Skipping...
# Running data for yabrud: 428 of 1000
# Running data for coolum beach: 429 of 1000
# Running data for florianopolis: 430 of 1000
# Running data for jiwani: 431 of 1000
# Running data for acapulco: 432 of 1000
# Running data for rawson: 433 of 1000
# Running data for lichinga: 434 of 1000
# Data returned null, Skipping...
# Running data for kasempa: 436 of 1000
# Running data for ahar: 437 of 1000
# Running data for fairbanks: 438 of 1000
# Running data for redmond: 439 of 1000
# Running data for strelka: 440 of 1000
# Running data for shimoda: 441 of 1000
# Running data for brenham: 442 of 1000
# Running data for brusque: 443 of 1000
# Running data for ratchaburi: 444 of 1000
# Running data for nuevo casas grandes: 445 of 1000
# Data returned null, Skipping...
# Running data for la reforma: 447 of 1000
# Running data for jardim: 448 of 1000
# Running data for tarakan: 449 of 1000
# Running data for ivanishchi: 450 of 1000
# Running data for tilichiki: 451 of 1000
# Running data for imeni poliny osipenko: 452 of 1000
# Running data for port blair: 453 of 1000
# Running data for omboue: 454 of 1000
# Running data for trujillo: 455 of 1000
# Running data for kerman: 456 of 1000
# Running data for khovu-aksy: 457 of 1000
# Running data for magsingal: 458 of 1000
# Data returned null, Skipping...
# Running data for kudahuvadhoo: 460 of 1000
# Running data for tahta: 461 of 1000
# Running data for yaring: 462 of 1000
# Running data for barkhan: 463 of 1000
# Running data for vostok: 464 of 1000
# Running data for walvis bay: 465 of 1000
# Running data for luau: 466 of 1000
# Running data for road town: 467 of 1000
# Data returned null, Skipping...
# Running data for tigil: 469 of 1000
# Running data for itacoatiara: 470 of 1000
# Data returned null, Skipping...
# Running data for corinto: 472 of 1000
# Running data for hami: 473 of 1000
# Running data for bubaque: 474 of 1000
# Running data for itinga: 475 of 1000
# Data returned null, Skipping...
# Running data for adolfo lopez mateos: 477 of 1000
# Running data for pastavy: 478 of 1000
# Running data for utinga: 479 of 1000
# Running data for santa maria: 480 of 1000
# Running data for nizhnyaya tavda: 481 of 1000
# Data returned null, Skipping...
# Running data for ekhabi: 483 of 1000
# Running data for hagere selam: 484 of 1000
# Running data for komsomolskiy: 485 of 1000
# Running data for jasper: 486 of 1000
# Running data for kashi: 487 of 1000
# Running data for martapura: 488 of 1000
# Running data for hervey bay: 489 of 1000
# Running data for zyryanovsk: 490 of 1000
# Running data for zhigansk: 491 of 1000
# Running data for manggar: 492 of 1000
# Running data for barra do bugres: 493 of 1000
# Running data for izmalkovo: 494 of 1000
# Running data for kurud: 495 of 1000
# Running data for staroshcherbinovskaya: 496 of 1000
# Running data for san ramon: 497 of 1000
# Running data for indiana: 498 of 1000
# Running data for vao: 499 of 1000
# Data returned null, Skipping...
# Running data for jijiga: 501 of 1000
# Running data for abyek: 502 of 1000
# Running data for rosario do sul: 503 of 1000
# Running data for of: 504 of 1000
# Running data for chibombo: 505 of 1000
# Running data for sidi ali: 506 of 1000
# Running data for bakreswar: 507 of 1000
# Running data for mackay: 508 of 1000
# Data returned null, Skipping...
# Running data for marsa matruh: 510 of 1000
# Running data for samarai: 511 of 1000
# Running data for moyale: 512 of 1000
# Running data for tianpeng: 513 of 1000
# Running data for varzea grande: 514 of 1000
# Running data for algiers: 515 of 1000
# Running data for upernavik: 516 of 1000
# Running data for puerto del rosario: 517 of 1000
# Running data for roma: 518 of 1000
# Running data for waingapu: 519 of 1000
# Running data for lagos: 520 of 1000
# Running data for kampot: 521 of 1000
# Running data for enugu: 522 of 1000
# Running data for carnarvon: 523 of 1000
# Running data for zhob: 524 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for lagos: 527 of 1000
# Data returned null, Skipping...
# Running data for dingle: 529 of 1000
# Data returned null, Skipping...
# Running data for saint-pierre: 531 of 1000
# Running data for yulara: 532 of 1000
# Running data for birao: 533 of 1000
# Running data for mitchell: 534 of 1000
# Running data for ranghulu: 535 of 1000
# Running data for aksay: 536 of 1000
# Running data for hirara: 537 of 1000
# Running data for udayagiri: 538 of 1000
# Running data for tessalit: 539 of 1000
# Running data for abadszalok: 540 of 1000
# Running data for lake havasu city: 541 of 1000
# Running data for fort nelson: 542 of 1000
# Running data for aksu: 543 of 1000
# Running data for okha: 544 of 1000
# Running data for seoul: 545 of 1000
# Running data for kyzyl-suu: 546 of 1000
# Running data for matara: 547 of 1000
# Running data for kaeo: 548 of 1000
# Running data for monzon: 549 of 1000
# Running data for vila franca do campo: 550 of 1000
# Running data for tabuk: 551 of 1000
# Running data for lethem: 552 of 1000
# Running data for caibarien: 553 of 1000
# Running data for bonavista: 554 of 1000
# Running data for muros: 555 of 1000
# Data returned null, Skipping...
# Running data for meulaboh: 557 of 1000
# Running data for luanda: 558 of 1000
# Running data for ambilobe: 559 of 1000
# Running data for cabedelo: 560 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for te anau: 563 of 1000
# Running data for tam ky: 564 of 1000
# Running data for pomabamba: 565 of 1000
# Running data for richards bay: 566 of 1000
# Running data for hailey: 567 of 1000
# Running data for van: 568 of 1000
# Running data for wamba: 569 of 1000
# Running data for chauk: 570 of 1000
# Running data for parabel: 571 of 1000
# Running data for namibe: 572 of 1000
# Running data for khandyga: 573 of 1000
# Data returned null, Skipping...
# Running data for ulaangom: 575 of 1000
# Running data for tabas: 576 of 1000
# Data returned null, Skipping...
# Running data for harper: 578 of 1000
# Running data for port augusta: 579 of 1000
# Running data for korla: 580 of 1000
# Running data for san cristobal: 581 of 1000
# Running data for dabola: 582 of 1000
# Running data for murygino: 583 of 1000
# Data returned null, Skipping...
# Running data for altoona: 585 of 1000
# Running data for balkhash: 586 of 1000
# Running data for ramnagar: 587 of 1000
# Running data for pozo colorado: 588 of 1000
# Running data for conceicao do araguaia: 589 of 1000
# Running data for lovozero: 590 of 1000
# Running data for oum hadjer: 591 of 1000
# Running data for manadhoo: 592 of 1000
# Data returned null, Skipping...
# Running data for tagusao: 594 of 1000
# Running data for axim: 595 of 1000
# Running data for panguna: 596 of 1000
# Running data for hammerfest: 597 of 1000
# Running data for soyo: 598 of 1000
# Running data for edinburg: 599 of 1000
# Running data for hualmay: 600 of 1000
# Running data for sao joao da barra: 601 of 1000
# Running data for trinidad: 602 of 1000
# Running data for bhasawar: 603 of 1000
# Running data for blythe: 604 of 1000
# Running data for basoko: 605 of 1000
# Data returned null, Skipping...
# Running data for longonjo: 607 of 1000
# Data returned null, Skipping...
# Running data for kollam: 609 of 1000
# Running data for hof: 610 of 1000
# Running data for pakokku: 611 of 1000
# Running data for tarko-sale: 612 of 1000
# Running data for kurilsk: 613 of 1000
# Running data for zharkovskiy: 614 of 1000
# Data returned null, Skipping...
# Running data for morwa: 616 of 1000
# Running data for mitsamiouli: 617 of 1000
# Running data for kuching: 618 of 1000
# Running data for bilibino: 619 of 1000
# Running data for tangwani: 620 of 1000
# Running data for dafeng: 621 of 1000
# Running data for turayf: 622 of 1000
# Running data for ozernovskiy: 623 of 1000
# Running data for ferme-neuve: 624 of 1000
# Running data for ouadda: 625 of 1000
# Running data for nemuro: 626 of 1000
# Running data for belmonte: 627 of 1000
# Data returned null, Skipping...
# Running data for amalapuram: 629 of 1000
# Running data for kavaratti: 630 of 1000
# Running data for praia: 631 of 1000
# Running data for brae: 632 of 1000
# Running data for jinji: 633 of 1000
# Running data for ngunguru: 634 of 1000
# Running data for aykhal: 635 of 1000
# Running data for fort-shevchenko: 636 of 1000
# Running data for charcas: 637 of 1000
# Running data for furano: 638 of 1000
# Running data for alepe: 639 of 1000
# Running data for mecca: 640 of 1000
# Running data for yanam: 641 of 1000
# Running data for maltahohe: 642 of 1000
# Running data for kidal: 643 of 1000
# Running data for sorland: 644 of 1000
# Running data for arnedo: 645 of 1000
# Running data for lincoln: 646 of 1000
# Running data for karlstad: 647 of 1000
# Running data for celestun: 648 of 1000
# Running data for westport: 649 of 1000
# Running data for flinders: 650 of 1000
# Running data for vanimo: 651 of 1000
# Running data for mochumi: 652 of 1000
# Running data for ulundi: 653 of 1000
# Running data for olavarria: 654 of 1000
# Running data for the valley: 655 of 1000
# Running data for misantla: 656 of 1000
# Running data for kutum: 657 of 1000
# Running data for el tarra: 658 of 1000
# Running data for rupert: 659 of 1000
# Running data for caravelas: 660 of 1000
# Running data for sabang: 661 of 1000
# Running data for general higinio morinigo: 662 of 1000
# Running data for edd: 663 of 1000
# Running data for bathsheba: 664 of 1000
# Running data for nalagarh: 665 of 1000
# Running data for najran: 666 of 1000
# Running data for pueblo: 667 of 1000
# Running data for shihezi: 668 of 1000
# Running data for roald: 669 of 1000
# Running data for west wendover: 670 of 1000
# Data returned null, Skipping...
# Running data for bridgetown: 672 of 1000
# Running data for jiexiu: 673 of 1000
# Running data for alyangula: 674 of 1000
# Running data for san jeronimo: 675 of 1000
# Running data for tornio: 676 of 1000
# Running data for terracina: 677 of 1000
# Running data for xiongzhou: 678 of 1000
# Running data for azangaro: 679 of 1000
# Running data for raahe: 680 of 1000
# Running data for abu kamal: 681 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for kushima: 684 of 1000
# Running data for santa barbara: 685 of 1000
# Running data for shache: 686 of 1000
# Running data for vallenar: 687 of 1000
# Running data for north bend: 688 of 1000
# Running data for putina: 689 of 1000
# Running data for tromso: 690 of 1000
# Running data for westerland: 691 of 1000
# Running data for aksha: 692 of 1000
# Running data for victor harbor: 693 of 1000
# Running data for patacamaya: 694 of 1000
# Data returned null, Skipping...
# Running data for necochea: 696 of 1000
# Running data for morondava: 697 of 1000
# Running data for san matias: 698 of 1000
# Running data for kano: 699 of 1000
# Running data for majene: 700 of 1000
# Running data for shu: 701 of 1000
# Running data for monrovia: 702 of 1000
# Running data for noo: 703 of 1000
# Running data for mauganj: 704 of 1000
# Running data for domoni: 705 of 1000
# Running data for kharitonovo: 706 of 1000
# Running data for takoradi: 707 of 1000
# Data returned null, Skipping...
# Running data for arlit: 709 of 1000
# Running data for marica: 710 of 1000
# Running data for kruisfontein: 711 of 1000
# Running data for mumbwa: 712 of 1000
# Data returned null, Skipping...
# Running data for pisco: 714 of 1000
# Running data for thanh hoa: 715 of 1000
# Running data for massillon: 716 of 1000
# Data returned null, Skipping...
# Running data for xichang: 718 of 1000
# Running data for margate: 719 of 1000
# Running data for presidencia roque saenz pena: 720 of 1000
# Running data for berezovyy: 721 of 1000
# Running data for qingdao: 722 of 1000
# Data returned null, Skipping...
# Running data for devonport: 724 of 1000
# Running data for severinia: 725 of 1000
# Running data for nurota: 726 of 1000
# Running data for gwadar: 727 of 1000
# Running data for nouadhibou: 728 of 1000
# Running data for parchim: 729 of 1000
# Running data for oistins: 730 of 1000
# Running data for yuncheng: 731 of 1000
# Running data for sao felix do xingu: 732 of 1000
# Running data for san luis: 733 of 1000
# Running data for champagnole: 734 of 1000
# Running data for yara: 735 of 1000
# Running data for labuhan: 736 of 1000
# Running data for nenjiang: 737 of 1000
# Data returned null, Skipping...
# Running data for karasjok: 739 of 1000
# Running data for bima: 740 of 1000
# Data returned null, Skipping...
# Running data for warrnambool: 742 of 1000
# Running data for maues: 743 of 1000
# Running data for tual: 744 of 1000
# Running data for mahuta: 745 of 1000
# Running data for ginir: 746 of 1000
# Running data for tra vinh: 747 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for uyuni: 750 of 1000
# Running data for teruel: 751 of 1000
# Running data for xuanzhou: 752 of 1000
# Running data for borogontsy: 753 of 1000
# Running data for ishigaki: 754 of 1000
# Running data for jining: 755 of 1000
# Running data for dukat: 756 of 1000
# Running data for camargo: 757 of 1000
# Running data for oktyabrskiy: 758 of 1000
# Running data for griffith: 759 of 1000
# Running data for larsnes: 760 of 1000
# Running data for alice springs: 761 of 1000
# Running data for coahuayana: 762 of 1000
# Running data for kununurra: 763 of 1000
# Running data for saint-joseph: 764 of 1000
# Running data for kargasok: 765 of 1000
# Running data for punta cardon: 766 of 1000
# Data returned null, Skipping...
# Running data for buraydah: 768 of 1000
# Running data for carolina: 769 of 1000
# Running data for corpus christi: 770 of 1000
# Running data for kefamenanu: 771 of 1000
# Running data for bogale: 772 of 1000
# Data returned null, Skipping...
# Running data for reforma: 774 of 1000
# Running data for varhaug: 775 of 1000
# Running data for ko samui: 776 of 1000
# Running data for baft: 777 of 1000
# Running data for ornskoldsvik: 778 of 1000
# Data returned null, Skipping...
# Running data for sechura: 780 of 1000
# Running data for pyshchug: 781 of 1000
# Running data for bati: 782 of 1000
# Running data for linhares: 783 of 1000
# Running data for chatellerault: 784 of 1000
# Running data for batsfjord: 785 of 1000
# Running data for liverpool: 786 of 1000
# Data returned null, Skipping...
# Running data for sinnamary: 788 of 1000
# Running data for gramsh: 789 of 1000
# Running data for mogadishu: 790 of 1000
# Data returned null, Skipping...
# Running data for sicamous: 792 of 1000
# Running data for santa rosa: 793 of 1000
# Running data for paramonga: 794 of 1000
# Running data for waipawa: 795 of 1000
# Running data for cabra: 796 of 1000
# Running data for serenje: 797 of 1000
# Running data for neuquen: 798 of 1000
# Running data for bafq: 799 of 1000
# Data returned null, Skipping...
# Running data for hamilton: 801 of 1000
# Running data for thinadhoo: 802 of 1000
# Running data for pevek: 803 of 1000
# Running data for kunming: 804 of 1000
# Data returned null, Skipping...
# Running data for chumikan: 806 of 1000
# Running data for matagami: 807 of 1000
# Running data for goya: 808 of 1000
# Running data for limbang: 809 of 1000
# Data returned null, Skipping...
# Running data for urengoy: 811 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for grand-santi: 814 of 1000
# Running data for plettenberg bay: 815 of 1000
# Running data for kuusamo: 816 of 1000
# Running data for kisangani: 817 of 1000
# Running data for rantepao: 818 of 1000
# Running data for nouakchott: 819 of 1000
# Running data for kodinsk: 820 of 1000
# Running data for leh: 821 of 1000
# Running data for chabahar: 822 of 1000
# Running data for cockburn town: 823 of 1000
# Running data for bad sooden-allendorf: 824 of 1000
# Running data for geraldton: 825 of 1000
# Running data for kushiro: 826 of 1000
# Running data for sept-iles: 827 of 1000
# Running data for conceicao do coite: 828 of 1000
# Running data for noshiro: 829 of 1000
# Running data for tshikapa: 830 of 1000
# Running data for mineral wells: 831 of 1000
# Running data for voskresenskoye: 832 of 1000
# Running data for turukhansk: 833 of 1000
# Running data for upata: 834 of 1000
# Running data for umm lajj: 835 of 1000
# Running data for scarborough: 836 of 1000
# Running data for nhulunbuy: 837 of 1000
# Running data for tutoia: 838 of 1000
# Running data for xinqing: 839 of 1000
# Running data for estelle: 840 of 1000
# Running data for farah: 841 of 1000
# Running data for xixiang: 842 of 1000
# Data returned null, Skipping...
# Running data for tapejara: 844 of 1000
# Running data for sladkovo: 845 of 1000
# Running data for gornopravdinsk: 846 of 1000
# Running data for ballarpur: 847 of 1000
# Running data for ereymentau: 848 of 1000
# Running data for homer: 849 of 1000
# Running data for tocopilla: 850 of 1000
# Running data for coruripe: 851 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for ambam: 854 of 1000
# Running data for grand gaube: 855 of 1000
# Running data for rehoboth: 856 of 1000
# Running data for lubumbashi: 857 of 1000
# Running data for bonthe: 858 of 1000
# Running data for bukachacha: 859 of 1000
# Running data for osakarovka: 860 of 1000
# Running data for caconda: 861 of 1000
# Data returned null, Skipping...
# Running data for moerai: 863 of 1000
# Running data for tahoua: 864 of 1000
# Running data for port keats: 865 of 1000
# Running data for dombarovskiy: 866 of 1000
# Running data for jaltenango: 867 of 1000
# Running data for bani walid: 868 of 1000
# Running data for jizan: 869 of 1000
# Running data for tananger: 870 of 1000
# Running data for nivala: 871 of 1000
# Running data for kankakee: 872 of 1000
# Data returned null, Skipping...
# Running data for quelimane: 874 of 1000
# Running data for fort atkinson: 875 of 1000
# Running data for alihe: 876 of 1000
# Data returned null, Skipping...
# Running data for marsabit: 878 of 1000
# Running data for pyinmana: 879 of 1000
# Running data for miraflores: 880 of 1000
# Data returned null, Skipping...
# Running data for bikin: 882 of 1000
# Running data for zarechnyy: 883 of 1000
# Running data for svetlaya: 884 of 1000
# Running data for bud: 885 of 1000
# Running data for dogondoutchi: 886 of 1000
# Running data for eldorado: 887 of 1000
# Running data for pacifica: 888 of 1000
# Running data for tommot: 889 of 1000
# Running data for severobaykalsk: 890 of 1000
# Running data for quang ngai: 891 of 1000
# Running data for pangkalanbuun: 892 of 1000
# Data returned null, Skipping...
# Running data for beloha: 894 of 1000
# Running data for srandakan: 895 of 1000
# Running data for mao: 896 of 1000
# Running data for gweta: 897 of 1000
# Data returned null, Skipping...
# Running data for rakitnoye: 899 of 1000
# Data returned null, Skipping...
# Running data for galveston: 901 of 1000
# Running data for yelatma: 902 of 1000
# Running data for santa cruz: 903 of 1000
# Running data for toma: 904 of 1000
# Running data for san juan de los morros: 905 of 1000
# Running data for oranjemund: 906 of 1000
# Running data for divnomorskoye: 907 of 1000
# Data returned null, Skipping...
# Running data for xingyi: 909 of 1000
# Running data for alta floresta: 910 of 1000
# Running data for kashiwazaki: 911 of 1000
# Running data for hermiston: 912 of 1000
# Running data for sterling: 913 of 1000
# Running data for oksfjord: 914 of 1000
# Running data for gamba: 915 of 1000
# Data returned null, Skipping...
# Running data for skibbereen: 917 of 1000
# Running data for iracoubo: 918 of 1000
# Running data for storm lake: 919 of 1000
# Running data for taltal: 920 of 1000
# Running data for la ronge: 921 of 1000
# Running data for myitkyina: 922 of 1000
# Running data for kenai: 923 of 1000
# Running data for sibanicu: 924 of 1000
# Running data for pekalongan: 925 of 1000
# Running data for mendoza: 926 of 1000
# Running data for bom jardim: 927 of 1000
# Running data for willowmore: 928 of 1000
# Running data for emerald: 929 of 1000
# Running data for moisakula: 930 of 1000
# Running data for batemans bay: 931 of 1000
# Running data for gizo: 932 of 1000
# Running data for progreso: 933 of 1000
# Running data for nizwa: 934 of 1000
# Data returned null, Skipping...
# Running data for lubango: 936 of 1000
# Running data for cadillac: 937 of 1000
# Running data for sao desiderio: 938 of 1000
# Running data for port macquarie: 939 of 1000
# Data returned null, Skipping...
# Running data for itoman: 941 of 1000
# Running data for koslan: 942 of 1000
# Running data for tanda: 943 of 1000
# Running data for excelsior springs: 944 of 1000
# Running data for puerto vallarta: 945 of 1000
# Running data for mountain home: 946 of 1000
# Running data for bay roberts: 947 of 1000
# Running data for anadyr: 948 of 1000
# Running data for zambezi: 949 of 1000
# Running data for liberia: 950 of 1000
# Running data for aloleng: 951 of 1000
# Data returned null, Skipping...
# Running data for maine-soroa: 953 of 1000
# Running data for khilok: 954 of 1000
# Running data for noumea: 955 of 1000
# Running data for abashiri: 956 of 1000
# Running data for aksarka: 957 of 1000
# Running data for kibungo: 958 of 1000
# Running data for la libertad: 959 of 1000
# Running data for kiruna: 960 of 1000
# Running data for champerico: 961 of 1000
# Running data for ketchikan: 962 of 1000
# Data returned null, Skipping...
# Running data for miandrivazo: 964 of 1000
# Running data for novoshcherbinovskaya: 965 of 1000
# Running data for jega: 966 of 1000
# Running data for kichera: 967 of 1000
# Running data for manaure: 968 of 1000
# Running data for sirpur: 969 of 1000
# Running data for nago: 970 of 1000
# Running data for sibolga: 971 of 1000
# Running data for goure: 972 of 1000
# Running data for hanzhong: 973 of 1000
# Running data for mandan: 974 of 1000
# Running data for santo antonio do sudoeste: 975 of 1000
# Data returned null, Skipping...
# Running data for dickson: 977 of 1000
# Data returned null, Skipping...
# Running data for miles city: 979 of 1000
# Running data for south venice: 980 of 1000
# Running data for ola: 981 of 1000
# Running data for vernon: 982 of 1000
# Running data for fiumicino: 983 of 1000
# Running data for mastung: 984 of 1000
# Running data for la rioja: 985 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for nabire: 988 of 1000
# Data returned null, Skipping...
# Running data for nuevitas: 990 of 1000
# Running data for bykivka: 991 of 1000
# Running data for lake charles: 992 of 1000
# Running data for charlestown: 993 of 1000
# Running data for bloemfontein: 994 of 1000
# Running data for ambovombe: 995 of 1000
# Data returned null, Skipping...
# Data returned null, Skipping...
# Running data for ponta do sol: 998 of 1000
# Running data for mounana: 999 of 1000

# %%
# Convert to dataframe

cities_df = pd.DataFrame(weather_data_list)

cities_df = cities_df[['City',
                       'Country',
                       'Longitude',
                       'Latitude',
                       'Max Temperature',
                       'Humidity',
                       'Cloud Cover',
                       'Wind Speed']]

cities_df.to_csv('CitiesDataFrame.csv')
cities_df.head()
# Out:
#            City Country  Longitude  Latitude  Max Temperature  Humidity  \
# 0         sitka      us     -99.65     37.17            17.37        65
# 1          aden      ye      45.03     12.79            76.32       100
# 2     nishihara      jp     139.53     35.74            50.00        49
# 3     marystown      ca     -55.16     47.17            13.05       100
# 4  punta arenas      cl     -70.91    -53.16            50.00        81
#
#    Cloud Cover  Wind Speed
# 0            0        3.18
# 1           76       12.80
# 2           20        6.93
# 3            8        3.74
# 4           75       10.29

# %%
# World Map, City Coordinate Distribution

cities_df.plot.scatter('Longitude', 
                       'Latitude',
                       title='Data Distribution',
                       s=40,
                       ylim=[-90,90],
                       color='LightBlue',
                       edgecolor='Black',
                       grid=True) 
plt.savefig('CityDistribution.png')

# %%
# Lat v. Temp

cities_df.plot.scatter('Latitude', 
                       'Max Temperature', 
                       title='Heat by Latitude', 
                       marker='o', 
                       s=40,
                       xlim=[-90, 90],
                       color='LightBlue', 
                       edgecolor='black', 
                       grid=True)
plt.savefig('MaxTempByLat.png')

# %%
#Lat v. Humidity

cities_df.plot.scatter('Latitude', 
                       'Humidity', 
                       title='Humidity over Latitude', 
                       marker='o', 
                       s=40,
                       xlim=[-90, 90],                       
                       color='Magenta', 
                       edgecolor='black', 
                       grid=True)
plt.savefig('HumidByLat.png')

# %%
#Lat v. Clouds

cities_df.plot.scatter('Latitude', 
                       'Cloud Cover', 
                       title='Cloud Cover over Latitude', 
                       marker='o', 
                       s=40,
                       xlim=[-90, 90],
                       color='Red', 
                       edgecolor='black', 
                       grid=True)
plt.savefig('CloudByLat.png')

# %%
# Lat v. Wind

cities_df.plot.scatter('Latitude', 
                       'Wind Speed', 
                       title='Latitude v. Wind Speed', 
                       marker='o', 
                       s=40,
                       xlim=[-90, 90],
                       color='Blue', 
                       edgecolor='black', 
                       grid=True)
plt.savefig('WindByLat.png')
